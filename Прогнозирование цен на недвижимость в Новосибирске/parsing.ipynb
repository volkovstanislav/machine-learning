# %%
import re
import sys
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup
from urllib.parse import quote
from sklearn import preprocessing
from urllib.request import urlopen
from matplotlib import pyplot as plt


pd.set_option('display.max_columns', 49)
# %matplotlib inline

# %%
path = r"/Users/stanislav/Мои документы/ml/1. developer/"
path + "flats_25.10.2018.csv"
# Out:
# '/Users/stanislav/Мои документы/ml/1. developer/flats_25.10.2018.csv'

# %%
data = pd.read_csv(path + "flats_25.10.2018.csv", sep=";",low_memory=False, encoding="utf-8")
data.head()
# Out:
#    Cart_Number          Feature  Rooms_Number            Object_Type  \
# 0    100316920  Продана не нами             1  Улучшенной планировки
# 1    100316924  Продана не нами             1  Улучшенной планировки
# 2     10103978  Продана не нами             1  Улучшенной планировки
# 3     10100878  Продана не нами             1  Улучшенной планировки
# 4     10104701  Продана не нами             1  Улучшенной планировки
#
#    Object_Type_ID   Settlement  Settlement_ID      District  District_Id  \
# 0               3  Новосибирск              1  Заельцовский            3
# 1               3  Новосибирск              1  Заельцовский            3
# 2               3  Новосибирск              1   Центральный           10
# 3               3  Новосибирск              1   Центральный           10
# 4               3  Новосибирск              1   Центральный           10
#
#              Street  Street_Id House_Number         Metro  Metro_ID  Metro_m  \
# 0  Красный проспект        901          181  Заельцовская       283     2890
# 1  Красный проспект        901          181  Заельцовская       283     2890
# 2  Красный проспект        900          181  Заельцовская       283     2830
# 3  Красный проспект        900          181  Заельцовская       283     2830
# 4  Красный проспект        900          181  Заельцовская       283     2830
#
#   Flats_Plan  Flats_Plan_ID  Stor  Storeys    Wall  Wall_ID Space_Total  \
# 0        NaN              0    13       17  Кирпич        2        54,1
# 1        NaN              0    10       17  Кирпич        2        54,5
# 2        NaN              0     8       17  Кирпич        2          37
# 3        NaN              0     2       17  Кирпич        2          42
# 4        NaN              0    13       17  Кирпич        2          28
#
#   Space_Living Space_Kitchen     ...       Lodgee_Num             Sost  \
# 0           18          21,2     ...                1      Самоотделка
# 1           18          21,1     ...                1  Требует ремонта
# 2            0             0     ...                0              NaN
# 3            0             0     ...                0              NaN
# 4            0             0     ...                0         Отличное
#
#    Sost_ID       Clozet Clozet_ID      lat     Long  Date_Postr  \
# 0        9  Совмещенный         8  55,0725  82,9069        2010
# 1        4   Раздельный         9  55,0725  82,9069        2010
# 2        0          NaN         0  55,0725  82,9068        2008
# 3        0          NaN         0  55,0725  82,9068        2008
# 4        6          NaN         0  55,0725  82,9068        2008
#
#                Date_Create                             Childrens_leisure  \
# 0  2009-04-21 00:00:00.000  Спектр, центр развития и творчества молодежи
# 1  2009-08-17 00:00:00.000  Спектр, центр развития и творчества молодежи
# 2  2016-09-27 10:07:31.490  Спектр, центр развития и творчества молодежи
# 3  2018-07-28 08:22:15.223  Спектр, центр развития и творчества молодежи
# 4  2017-06-23 10:36:04.610  Спектр, центр развития и творчества молодежи
#
#    Childrens_Distance Childrens_Count  \
# 0               337.0            12.0
# 1               337.0            12.0
# 2               337.0            12.0
# 3               337.0            12.0
# 4               337.0            12.0
#
#                                       Schools  Schools_Distance  \
# 0  Сибирский Кадетский Корпус, школа-интернат             142.0
# 1  Сибирский Кадетский Корпус, школа-интернат             142.0
# 2  Сибирский Кадетский Корпус, школа-интернат             142.0
# 3  Сибирский Кадетский Корпус, школа-интернат             142.0
# 4  Сибирский Кадетский Корпус, школа-интернат             142.0
#
#    Schools_Count                                     Kindergarten  \
# 0            3.0  Берёзка, детский сад №272 комбинированного вида
# 1            3.0  Берёзка, детский сад №272 комбинированного вида
# 2            3.0  Берёзка, детский сад №272 комбинированного вида
# 3            3.0  Берёзка, детский сад №272 комбинированного вида
# 4            3.0  Берёзка, детский сад №272 комбинированного вида
#
#    Kindergarten_Distance  Kindergarten_Count  \
# 0                  278.0                 5.0
# 1                  278.0                 5.0
# 2                  278.0                 5.0
# 3                  278.0                 5.0
# 4                  278.0                 5.0
#
#                               Products  Products_Distance  Products_Count  \
# 0  У соседа, продовольственный магазин              113.0            17.0
# 1  У соседа, продовольственный магазин              113.0            17.0
# 2  У соседа, продовольственный магазин              113.0            17.0
# 3  У соседа, продовольственный магазин              113.0            17.0
# 4  У соседа, продовольственный магазин              113.0            17.0
#
#                         Sport  Sport_Distance  Sport_Count
# 0  Солнечный, детский бассейн           364.0          0.0
# 1  Солнечный, детский бассейн           364.0          0.0
# 2  Солнечный, детский бассейн           364.0          0.0
# 3  Солнечный, детский бассейн           364.0          0.0
# 4  Солнечный, детский бассейн           364.0          0.0
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Формируем полные адреса квартир

# %%
data["House_Number"]=data["House_Number"].str.replace(" ","").str.lower()

# %%
data["full_address_home"] = "Новосибирск, " + data["District"] + ", " + data["Street"] + ", " + data["House_Number"]
data["full_address_home"] = data["full_address_home"].str.replace(" ","+")
df_full_address["full_address_home"] = data["full_address_home"].drop_duplicates()
df_full_address.head()
# Out:
# 0      Новосибирск,+Заельцовский,+Красный+проспект,+181
# 2       Новосибирск,+Центральный,+Красный+проспект,+181
# 38    Новосибирск,+Заельцовский,+Красный+проспект,+2...
# 39     Новосибирск,+Заельцовский,+Красный+проспект,+232
# 82          Новосибирск,+Заельцовский,+Шевцовой+2-я,+37
# Name: full_address_home, dtype: object

# %%
def add_info_geo(data,address):
    latit = list()
    longit = list()
    for i in range(len(data)):
        if (i%1000==0):
            print(i)
            print("https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i]))
        main_url = "https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i])
        html = urlopen(main_url)
        soup = BeautifulSoup(html.read(), "html.parser")
        featuremember = soup.find("featuremember")     
        geo_cord = featuremember.find("pos").text.split(" ")  
        latit.append(geo_cord[1])
        longit.append(geo_cord[0])
        
    data["latit"] = latit
    data["Longit"] = longit
    return data

# %%
full_address = add_info_geo(df_full_address,"full_address_home")
full_address.head(10)
# Out:
# 0
# https://geocode-maps.yandex.ru/1.x/?geocode=%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA%2C%2B%D0%97%D0%B0%D0%B5%D0%BB%D1%8C%D1%86%D0%BE%D0%B2%D1%81%D0%BA%D0%B8%D0%B9%2C%2B%D0%9A%D1%80%D0%B0%D1%81%D0%BD%D1%8B%D0%B9%2B%D0%BF%D1%80%D0%BE%D1%81%D0%BF%D0%B5%D0%BA%D1%82%2C%2B181
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-ddd7b2cb4501> in <module>
# ----> 1 full_address = add_info_geo(df_full_address,"full_address_home")
#       2 full_address.head(10)
#
# <ipython-input-160-7f365a841278> in add_info_geo(data, address)
#       6             print(i)
#       7             print("https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i]))
# ----> 8         main_url = "https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i])
#       9         html = urlopen(main_url)
#      10         soup = BeautifulSoup(html.read(), "html.parser")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %% [markdown]
# ### GPS координаты станций Новосибирского метро

# %%
data["Metro"].unique()
# Out:
# array(['Заельцовская', nan, 'Правый берег', 'Площадь Маркса',
#        'Студенческая', 'Берёзовая роща', 'Октябрьская', 'Золотая Нива',
#        'Речной вокзал', 'Площадь Гарина-Михайловского', 'Площадь Ленина',
#        'Маршала Покрышкина', 'Красный проспект', 'Сибирская',
#        'Гагаринская', 'Левый берег'], dtype=object)

# %%
metro_geo = {"Заельцовская" : ["55.059410", "82.912488"],
"Гагаринская" : ["55.051071", "82.914770"],
"Красный проспект" : ["55.041168", "82.917429"],
"Площадь Ленина" : ["55.030003", "82.920492"],
"Октябрьская" : ["55.019134", "82.939303"],
"Речной вокзал" : ["55.008573", "82.937821"],
"Студенческая" : ["54.989140", "82.906649"],
"Площадь Маркса" : ["54.983050", "82.893013"],
"Площадь Гарина-Михайловского" : ["55.035385", "82.898780"],
"Сибирская" : ["55.042323", "82.919298"],
"Маршала Покрышкина" : ["55.043768", "82.935539"],
"Берёзовая роща" : ["55.043355", "82.953056"],
"Золотая Нива" : ["55.037969", "82.976215"]}
metro_geo = pd.DataFrame(metro_geo)
metro_geo.head()
# Out:
#   Заельцовская Гагаринская Красный проспект Площадь Ленина Октябрьская  \
# 0    55.059410   55.051071        55.041168      55.030003   55.019134
# 1    82.912488   82.914770        82.917429      82.920492   82.939303
#
#   Речной вокзал Студенческая Площадь Маркса Площадь Гарина-Михайловского  \
# 0     55.008573    54.989140      54.983050                    55.035385
# 1     82.937821    82.906649      82.893013                    82.898780
#
#    Сибирская Маршала Покрышкина Берёзовая роща Золотая Нива
# 0  55.042323          55.043768      55.043355    55.037969
# 1  82.919298          82.935539      82.953056    82.976215

# %% [markdown]
# ### Парсинг адреса учерждений с сайта
# https://neagent.info/novosibirsk/infrastructure/ <br />
# Инфраструктура Новосибирска, Метро, станции, Университеты, Детские сады, Школы, Торговые центры, Магазины, торговые сети

# %% [markdown]
# * **Образовательные учреждения**

# %%
schools = pd.DataFrame(columns=["name","address"])
main_school_url = "https://neagent.info/novosibirsk/school/"
site_list = ["licei","chastnye","sosch","gimnazii"]

# %%
name = list()
adr = list()
for l in site_list:
    url = main_school_url + l
    html = urlopen(url)
    soup = BeautifulSoup(html.read(), "html.parser")
    table = soup.find("table", {"class": "district-markerlist"})
    obj = table.findAll("div", {"class" : "params-marker-desc"})
    for i in obj:
        address = i.find_all("p")
        name.append(address[1].text.lstrip())
        adr.append(address[0].text.lstrip())

school = pd.DataFrame({"name":name, "address":adr})
school["address_for_url"] = "Новосибирск,+"+school["address"].str.replace(" ","+")
school.head()
# Out:
#                                                name  \
# 0                                     МАОУ Лицей №6
# 1                                     МАОУ Лицей №7
# 2  МБОУ Аэрокосмический лицей имени Ю.В. Кондратюка
# 3                                   МБОУ Лицей №113
# 4                                     МБОУ Лицей №9
#
#                                      address  \
# 0               г. Бердск, ул. Горького, 7/3
# 1               г. Бердск,   ул. Ленина, 104
# 2       Дзержинский, ул.  Индустриальная, 4а
# 3  Дзержинский, ул.  Бориса Богаткова, 241/1
# 4         Железнодорожный, ул. 1905 года, 41
#
#                                      address_for_url
# 0          Новосибирск,+г.+Бердск,+ул.+Горького,+7/3
# 1          Новосибирск,+г.+Бердск,+++ул.+Ленина,+104
# 2  Новосибирск,+Дзержинский,+ул.++Индустриальная,+4а
# 3  Новосибирск,+Дзержинский,+ул.++Бориса+Богатков...
# 4    Новосибирск,+Железнодорожный,+ул.+1905+года,+41

# %%
# Координаты
school = add_info_geo(school,"address_for_url")
school.head()
# Out:
# 0
#                                                name  \
# 0                                     МАОУ Лицей №6
# 1                                     МАОУ Лицей №7
# 2  МБОУ Аэрокосмический лицей имени Ю.В. Кондратюка
# 3                                   МБОУ Лицей №113
# 4                                     МБОУ Лицей №9
#
#                                      address  \
# 0               г. Бердск, ул. Горького, 7/3
# 1               г. Бердск,   ул. Ленина, 104
# 2       Дзержинский, ул.  Индустриальная, 4а
# 3  Дзержинский, ул.  Бориса Богаткова, 241/1
# 4         Железнодорожный, ул. 1905 года, 41
#
#                                      address_for_url      latit     Longit
# 0          Новосибирск,+г.+Бердск,+ул.+Горького,+7/3  54.759867  83.112022
# 1          Новосибирск,+г.+Бердск,+++ул.+Ленина,+104  54.756911  83.113433
# 2  Новосибирск,+Дзержинский,+ул.++Индустриальная,+4а   55.05547  82.970744
# 3  Новосибирск,+Дзержинский,+ул.++Бориса+Богатков...  55.039976  82.977931
# 4    Новосибирск,+Железнодорожный,+ул.+1905+года,+41  55.042504   82.90196

# %%
school.to_csv(path + "nov_schools.csv")

# %% [markdown]
# * **Университеты**

# %%
main_univer_url = "https://neagent.info/novosibirsk/university/"
short = list()
full = list()
html = urlopen(main_univer_url)
soup = BeautifulSoup(html.read(), "html.parser")
div = soup.find("div", {"class" : "contentblock"})
table = div.find("table")
tr = table.findAll("tr")

for i in tr:
    short_name = i.find("h2")
    full_name = i.find("p")
    if short_name and full_name:
        short.append(short_name.text.lstrip())
        full.append(full_name.text.lstrip())

univer = pd.DataFrame({"short_name":short, "full_name":full})
univer["address_for_url"] = univer["short_name"].str.replace(" ","+")
univer.head()
# Out:
#   short_name                                          full_name  \
# 0      СГУВТ  Сибирский государственный университет водного ...
# 1     СГУГиТ  Сибирский государственный университет геосисте...
# 2        НВИ  Новосибирский военный институт им. генерала ар...
# 3     НГУАДИ  Новосибирский государственный университет архи...
# 4       НГТУ  Новосибирский государственный технический унив...
#
#   address_for_url
# 0           СГУВТ
# 1          СГУГиТ
# 2             НВИ
# 3          НГУАДИ
# 4            НГТУ

# %%
univer["naddress"] = ""
univer["naddress"][0] = "ул. Щетинкина, 33, Новосибирск"
univer["naddress"][1] = "ул. Плахотного, 10"
univer["naddress"][2] = "ул. Ключ-Камышенское Плато, 6/2"
univer["naddress"][3] = "Красный просп., 38"
univer["naddress"][4] = "просп. Карла Маркса, 20"
univer["naddress"][5] = "Вилюйская ул., 28"
univer["naddress"][6] = "Советская ул., 31"
univer["naddress"][7] = "просп. Карла Маркса, 26"
univer["naddress"][8] = "Ленинградская ул., 113"
univer["naddress"][9] = "Нижегородская ул., 6"
univer["naddress"][10] = "ул. Дуси Ковальчук, 191"
univer["naddress"][11] = "ул. Медкадры, 8"
univer["naddress"][12] = "Каменская ул., 52/1,"
univer["naddress"][13] = "ул. Пирогова, 1, Советский район, микрорайон Академгородок"
univer["naddress"][14] = "ул. Революции, 6"
univer["naddress"][15] = "Красный просп., 52"
univer["naddress"][16] = "ул. Добролюбова, 160"
univer["naddress"][17] = "ул. Кирова, 86"

# %%
# Координаты
univer["address_for_url"] = univer["naddress"].str.replace(" ","+")
univer.head()
# Out:
#   short_name                                          full_name  \
# 0      СГУВТ  Сибирский государственный университет водного ...
# 1     СГУГиТ  Сибирский государственный университет геосисте...
# 2        НВИ  Новосибирский военный институт им. генерала ар...
# 3     НГУАДИ  Новосибирский государственный университет архи...
# 4       НГТУ  Новосибирский государственный технический унив...
#
#                    address_for_url                         naddress
# 0   ул.+Щетинкина,+33,+Новосибирск   ул. Щетинкина, 33, Новосибирск
# 1               ул.+Плахотного,+10               ул. Плахотного, 10
# 2  ул.+Ключ-Камышенское+Плато,+6/2  ул. Ключ-Камышенское Плато, 6/2
# 3               Красный+просп.,+38               Красный просп., 38
# 4          просп.+Карла+Маркса,+20          просп. Карла Маркса, 20

# %%
univer = add_info_geo(univer,"address_for_url")
univer.head()
# Out:
# 0
# https://geocode-maps.yandex.ru/1.x/?geocode=%D1%83%D0%BB.%2B%D0%A9%D0%B5%D1%82%D0%B8%D0%BD%D0%BA%D0%B8%D0%BD%D0%B0%2C%2B33%2C%2B%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA
#   short_name                                          full_name  \
# 0      СГУВТ  Сибирский государственный университет водного ...
# 1     СГУГиТ  Сибирский государственный университет геосисте...
# 2        НВИ  Новосибирский военный институт им. генерала ар...
# 3     НГУАДИ  Новосибирский государственный университет архи...
# 4       НГТУ  Новосибирский государственный технический унив...
#
#                    address_for_url                         naddress  \
# 0   ул.+Щетинкина,+33,+Новосибирск   ул. Щетинкина, 33, Новосибирск
# 1               ул.+Плахотного,+10               ул. Плахотного, 10
# 2  ул.+Ключ-Камышенское+Плато,+6/2  ул. Ключ-Камышенское Плато, 6/2
# 3               Красный+просп.,+38               Красный просп., 38
# 4          просп.+Карла+Маркса,+20          просп. Карла Маркса, 20
#
#        latit     Longit
# 0  55.028445  82.914546
# 1  54.986449  82.862857
# 2  54.984026  83.035396
# 3  55.031541    82.9206
# 4  53.196488  50.145477

# %%
univer.to_csv(path + "nov_univer.csv")

# %% [markdown]
# * **Муниципальные детские сады**

# %%
adr = list()
name = list()
main_kinder_url = "https://neagent.info/novosibirsk/kindergarten/municipalnye/"
html = urlopen(main_kinder_url)
soup = BeautifulSoup(html.read(), "html.parser")
table = soup.find("table", {"class": "district-markerlist"})
tr = table.findAll("tr")

for i in tr:
    div = i.find("div",{"class":"params-marker-desc"})
    if div:
        address = div.findAll("p")
        adr.append(address[0].text)
        name.append(address[1].text)
        
kinder = pd.DataFrame({"address":adr, "name":name})
kinder["address_for_url"] = "Новосибирск,+"+kinder["address"].str.replace(" ","+")
kinder = kinder.drop_duplicates()
kinder.head()
# Out:
#                                address  \
# 0        Дзержинский, ул. Фрунзе, 59/3
# 2   Дзержинский, пр. Дзержинского, 59а
# 3     Дзержинский, ул. Толбухина, 31/1
# 5        Дзержинский, ул. Есенина, 27а
# 6  Дзержинский, ул. Адриена Лежена, 21
#
#                                                 name  \
# 0       МКДОУ Детский сад №459 комбинированного вида
# 2       МКДОУ Детский сад №362 комбинированного вида
# 3      МКДОУ Детский сад № 457 комбинированного вида
# 5  МАДОУ Детский сад №373 комбинированного вида "...
# 6  МАДОУ Детский сад №373 комбинированного вида "...
#
#                                     address_for_url
# 0        Новосибирск,+Дзержинский,+ул.+Фрунзе,+59/3
# 2   Новосибирск,+Дзержинский,+пр.+Дзержинского,+59а
# 3     Новосибирск,+Дзержинский,+ул.+Толбухина,+31/1
# 5        Новосибирск,+Дзержинский,+ул.+Есенина,+27а
# 6  Новосибирск,+Дзержинский,+ул.+Адриена+Лежена,+21

# %%
kinder = add_info_geo(kinder,"address_for_url")
kinder.head()
# Out:
# 0
# https://geocode-maps.yandex.ru/1.x/?geocode=%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA%2C%2B%D0%94%D0%B7%D0%B5%D1%80%D0%B6%D0%B8%D0%BD%D1%81%D0%BA%D0%B8%D0%B9%2C%2B%D1%83%D0%BB.%2B%D0%A4%D1%80%D1%83%D0%BD%D0%B7%D0%B5%2C%2B59/3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-b804dc6c5c86> in <module>
# ----> 1 kinder = add_info_geo(kinder,"address_for_url")
#       2 kinder.head()
#
# <ipython-input-160-7f365a841278> in add_info_geo(data, address)
#       6             print(i)
#       7             print("https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i]))
# ----> 8         main_url = "https://geocode-maps.yandex.ru/1.x/?geocode="+quote(data[address][i])
#       9         html = urlopen(main_url)
#      10         soup = BeautifulSoup(html.read(), "html.parser")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
kinder.to_csv(path + "nov_kinder.csv")
