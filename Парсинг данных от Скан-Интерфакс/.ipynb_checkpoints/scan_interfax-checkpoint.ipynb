# %%
import re
import json
import requests
import warnings
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## Параметры

# %%
## Основной url для api запросов
main_url='https://gateway.scan-interfax.ru/'

login = 'kiselevI@open.ru'
password = 'lLd/ENl' 

## Подгрузка расшифровки
http_status_code = pd.read_csv(r'http_status_code.csv', sep=';', error_bad_lines=False, encoding="cp1251")

# %% [markdown]
# ---------------------

# %% [markdown]
# # Методы работы с аккаунтом

# %% [markdown]
# ## Авторизация

# %%
api_login = 'api/v1/account/login'
url = main_url + api_login
print(url)

## Параметры
params ={
  "login": login,
  "password": password
}

try:
    response = requests.post(url, json=params, verify=False)
    accessToken = response.json()['accessToken']
    print('- Результат запроса:',http_status_code[http_status_code['code']==response.status_code]['name'].values[0])
    print(http_status_code[http_status_code['code']==response.status_code]['message'].values[0])
    print('- Срок действия аккаунта до:',pd.to_datetime(response.json()['expire']).date())  
except BaseException as error:
    print('Ошибка запроса:',response.status_code)
    print(error.__doc__)
# Out:
# https://gateway.scan-interfax.ru/api/v1/account/login
# - Результат запроса: OK
# "Успешно". Запрос успешно обработан. Что значит "успешно", зависит от метода HTTP, который был запрошен:
# - Срок действия аккаунта до: 2020-03-28

# %% [markdown]
# ## Получение текущего баланса пользователя

# %%
api_balance = 'api/v1/account/balance'
url = main_url + api_balance
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

response = requests.get(url, headers=headers, verify=False)
print('-- Результат запроса:', response.status_code)
print('-Признак безлимитного тарифа:', response.json()['unlimited'])
print('-Остаток средств на счету (у.е.):', response.json()['balance'])
print('-Стоимость одного поискового терма (у.е.):',response.json()['searchTermCost'])
print('-Время до окончания ограничения на выполнение поиска (сек.):', response.json()['searchRateBlockPeriod'])
# Out:
# https://gateway.scan-interfax.ru/api/v1/account/balance
# -- Результат запроса: 200
# -Признак безлимитного тарифа: False
# -Остаток средств на счету (у.е.): 84482.0
# -Стоимость одного поискового терма (у.е.): 1.0
# -Время до окончания ограничения на выполнение поиска (сек.): 0

# %% [markdown]
# ## Получение историю покупок пользователя

# %%
api_hist = 'api/v1/account/purchaseHistory'
url = main_url + api_hist
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

response = requests.get(url, headers=headers, verify=False)
response.json()
# Out:
# https://gateway.scan-interfax.ru/api/v1/account/purchaseHistory
# {}

# %% [markdown]
# # Поиск документов в каталоге

# %%
# 3123027569
# 0275073194
# 5263081418
# 5752046628
# 5908048172
# 6660144200
# 7743095125
# 4727002311
# 6140005000
# 7804601371
# 3908602319
# 1102061710

# %%
api_find = 'api/v1/entities/findEntities'
url = main_url + api_find
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

params = {
  "matchTerm": "Газпром",
  "cardAvailable": True,
  "inn": "",
  "maxCountToReturn": 10000000
}

response = requests.post(url, json = params, headers=headers, verify=False)
print('Код запроса:', response.status_code)
print('По запрашиваемому клиенту было возвращено:',len(response.json()['entities']),'статей')
list_ent = []
# response.json()['entities'][0]['searchTerm']['mentionContext']
for ent in response.json()['entities']:
    list_ent.append({'entityId': ent['entityId'], 'entityType': ent['entityType'], 'name': ent['name'], 'searchTerm': ent['searchTerm']})

entities = pd.DataFrame(list_ent)
entities.head()
# Out:
# https://gateway.scan-interfax.ru/api/v1/entities/findEntities
# Код запроса: 200
# По запрашиваемому клиенту было возвращено: 187 статей
#    entityId entityType                       name  \
# 0    508982    company               Газпром, ПАО
# 1    521682    company         Газпром нефть, ПАО
# 2    519830    company               Банк ГПБ, АО
# 3    543421    company  Газпром Межрегионгаз, ООО
# 4   6970885    company  Газпром-Медиа Холдинг, АО
#
#                                           searchTerm
# 0  {'withStaff': False, 'operator': 'and', 'type'...
# 1  {'withStaff': False, 'operator': 'and', 'type'...
# 2  {'withStaff': False, 'operator': 'and', 'type'...
# 3  {'withStaff': False, 'operator': 'and', 'type'...
# 4  {'withStaff': False, 'operator': 'and', 'type'...

# %% [markdown]
# ## Получение подробной информации об объекте, заданном по ID

# %%
api_get_obj= 'api/v1/entities/519830'
url = main_url + api_get_obj
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

response = requests.get(url, headers=headers, verify=False)
print('Код запроса:', response.status_code)
obj_info = {'image': response.json()['image'], 'description': response.json()['description'], \
            'entityId': response.json()['entityId'], 'entityType': response.json()['entityType'],
            'name': response.json()['name']}

df = pd.DataFrame(obj_info, index=[0])
df.head()
# Out:
# https://gateway.scan-interfax.ru/api/v1/entities/519830
# Код запроса: 500
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8723b9c7cc08> in <module>
#       9 response = requests.get(url, headers=headers, verify=False)
#      10 print('Код запроса:', response.status_code)
# ---> 11 obj_info = {'image': response.json()['image'], 'description': response.json()['description'], \
#      12             'entityId': response.json()['entityId'], 'entityType': response.json()['entityType'],
#      13             'name': response.json()['name']}
#
# KeyError: 'image'

# %% [markdown]
# ## Получение значения Индекса репутационного риска (ИРР) по заданной организации

# %%
api_irr = 'api/v1/entities/getRisk'
url = main_url + api_irr
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

params = {
   'entityId' : 519830
}

response = requests.post(url, json=params, headers=headers, verify=False)
print('Код запроса:', response.status_code)
res = pd.DataFrame({'value':response.json()['value'], 'riskLevel':response.json()['riskLevel'], 'documentsCount': response.json()['documentsCount'], 'documentsCountLevel':response.json()['documentsCountLevel']}, index=[0])
res.head()

# %% [markdown]
# ## Получение списка тем публикаций

# %%
api_subj= 'api/v1/entities/subjects'
url = main_url + api_subj
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

params = {
    'index' : 0,
    'pageSize': 1000
}

response = requests.get(url, params=params, headers=headers, verify=False)
print('Код запроса:', response.status_code)
response.json()

# %%
l = []
for el in response.json()['subjects']:
    try:
        l.append({'subjectId' : el['subjectId'],'name' : el['name'], 'parentId' : el['parentId']})
    except Exception as e:
        l.append({'subjectId' : el['subjectId'],'name' : el['name'], 'parentId' : 'нет'})

# %%
df = pd.DataFrame(l)
print(df.shape)
df.to_excel('subject_full.xlsx')

# %%
import itertools  

a = list(df['subjectId'].unique())
b = list(df['parentId'].unique())
c = list(itertools.product(a, b))

# %%
import networkx as nx

G=nx.Graph()
G.add_edges_from(c)
nx.draw_spring(G, )
# plt.savefig("simple_path.png")
# plt.show()

# %%
# import networkx as nx
import holoviews as hv
from holoviews import opts

# %%
 ### визуализация графов
hv.extension('bokeh')

# %%
# параметры для построения графов
# %opts Graph (edge_line_width=0.5)

# %%
# %opts Graph (node_size=5)

# %%
 # %opts Graph [width=800, height=800]

# %%
df = pd.read_excel('subject.xlsx')
df.head()

# %%
print(df.shape)
df = df[df['parentId'] != 'нет']
print(df.shape)

# %%
gr = nx.from_pandas_edgelist(df, 'subjectId', 'parentId')

# %%
gr

# %%
hv.Graph.from_networkx(gr, nx.layout.spring_layout)

# %% [markdown]
# ## Получение тематики источников

# %%
api_irr = 'api/v1/sources/topics'
url = main_url + api_irr
print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

response = requests.get(url, headers=headers, verify=False)
print('Код запроса:', response.status_code)
response.json()

# %% [markdown]
# # Cценарии

# %% [markdown]
# ## Загрузка архива публикаций

# %% [markdown]
# ### Поиск по юридическим лицам

# %%
## Загружаем данные от Михеевой
data_b =pd.read_excel(r'C:\Users\VOLKOV_STAN\Documents\Скан-Интерфакс\Мониторинг СКАН Интерфакс (Белова).xlsx',
                         converters={'inn':str})
print(data_b.shape)
# собираем словарь
inn_list = list(data_b['inn'].unique())
companiesToSearch = []
for inn in inn_list:
    if len(inn) == 10:
        companiesToSearch.append({"inn":inn, "documentsCount": 100000})
# Out:
# (2071, 1)

# %%
## Загрузка архива публикаций
api_find_comp = 'api/v1/search/findByCompaniesList'
url = main_url + api_find_comp

print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

params = {
  "companiesToSearch": companiesToSearch,
  "period": {
    "startDate": "2019-03-26T00:00:00",
    "endDate": "2020-03-26T23:59:59"
  },
  "mentionContext": "any",
  "similarMode": "similar",
  "sortType": "newFirst",
  "dateSearchType": "publicationDate"
}

response = requests.post(url, json=params, headers=headers, verify=False)
print('Код запроса:', response.status_code)
res = response.json()
# Out:
# https://gateway.scan-interfax.ru/api/v1/search/findByCompaniesList
# Код запроса: 200

# %%
len(res['companiesSearchResult'])
# Out:
# 1959

# %%
df_list = []
for elem in res['companiesSearchResult']:
    mes_list = []
    for doc in elem['documentIds']:
        mes_list.append(doc)
    try:
        df_list.append({'company': elem['company']['inn'], 'queryCode':elem['queryCode'], 'totalCount': elem['totalCount'], 'documentIds':mes_list})
    except Exception as e:
        continue
        
result = pd.DataFrame(df_list)
result['len_documentIds'] = result['documentIds'].apply(lambda x: len(x))
result.head()
# Out:
#       company                         queryCode  totalCount  \
# 0  6678034985  813811ece60d474af4de7b29b682d3e0          51
# 1  5406681543  af8bd3cfbcad886193798ab7116ad411           1
# 2  7814566648  d2c8a496e69f0bf1b25ab969451a6978          27
# 3  7805555551  17f855487305a3f625a8853d3b087779          11
# 4  6163099251  3c60e3760a33e96e3c2b1d85aed34699          23
#
#                                          documentIds  len_documentIds
# 0  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 1  [1:0YbCp+KAudC4UgfQmhhyY9CCcn7RmiDQmuKAoBV50Zt...                1
# 2  [1:Y9GTB9GJ4oCUItCOwq1g0Yor0Ycj0ZMiMNCm0INLCX4...               27
# 3  [1:D9CJMAXQj9CPRdCLwrfRmNCnN9CW4oSiQSo8MWgL0KY...               11
# 4  [1:GSQB0L7igJ3QoxPQltGf0J8V4oCUSOKAoELCrNCoSyI...               10

# %%
result = result[result['len_documentIds']>0]
print(result.shape)
result.head()
# Out:
# (5, 5)
#       company                         queryCode  totalCount  \
# 0  6678034985  813811ece60d474af4de7b29b682d3e0          51
# 1  5406681543  af8bd3cfbcad886193798ab7116ad411           1
# 2  7814566648  d2c8a496e69f0bf1b25ab969451a6978          27
# 3  7805555551  17f855487305a3f625a8853d3b087779          11
# 4  6163099251  3c60e3760a33e96e3c2b1d85aed34699          23
#
#                                          documentIds  len_documentIds
# 0  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 1  [1:0YbCp+KAudC4UgfQmhhyY9CCcn7RmiDQmuKAoBV50Zt...                1
# 2  [1:Y9GTB9GJ4oCUItCOwq1g0Yor0Ycj0ZMiMNCm0INLCX4...               27
# 3  [1:D9CJMAXQj9CPRdCLwrfRmNCnN9CW4oSiQSo8MWgL0KY...               11
# 4  [1:GSQB0L7igJ3QoxPQltGf0J8V4oCUSOKAoELCrNCoSyI...               10

# %% [markdown]
# ### Получение текстов найденных публикаций

# %%
api_find_doc = 'api/v1/search/getDocuments'
url = main_url + api_find_doc

print(url)

headers = {
    'Authorization': 'Bearer ' + accessToken
}

con_df = []
for k, v in result.iterrows():
    params = {
      "queryCode": v['queryCode'],
      "ids": v['documentIds'],
      "attributes": [
        "content",  "objects"
      ],
      "options": [
        "inlineImages"
      ]
    }
    
    try:
        response = requests.post(url, json=params, headers=headers, verify=False)
        print('Код запроса:', response.status_code)
        docs = response.json()
        doc_list = []
        for elem in docs['documents']:
            doc_list.append({'documentId': elem['documentId'],
        #                     'dedupClusterId': elem['dedupClusterId'],
                             'date': elem['date'],
                             'loadingDate': elem['loadingDate'],
                             'title': elem['title'],
                             'author': elem['author'],
                             'sourceId': elem['sourceId'],
                             'sourceName': elem['sourceName'],
                             'url': elem['url'],
                             'fullTextUnavailable': elem['fullTextUnavailable'],
                             'content': elem['content'],
                             'objects': elem['objects'],
                            'queryCode':v['queryCode']})
        news = pd.DataFrame(doc_list)
        news.to_excel('newx_'+str(k)+'.xlsx')
        con_df.append(news)
    except Exception as e:
        print(e)
        continue
        
news = pd.concat(con_df)
# Out:
# https://gateway.scan-interfax.ru/api/v1/search/getDocuments

# %% [markdown]
# -----------------------

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %%
news['title'] = news['title'].apply(lambda x: cleanhtml(x))
news['content'] = news['content'].apply(lambda x: cleanhtml(x))
news.head()
# Out:
#                                           documentId  \
# 0  1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oCm...
# 1  1:0Ycb0Y0gXAzQmDLRgALigKZfNQ0fwq7QpOKAlOKAptCm...
# 2  1:0KnQq9C54oSi0LTQlA8MB+KAucKu4oCa0IgqREo60LPQ...
# 3  1:PtCbLHIS0JDQhOKAudCL0KF10ZZuDtCkD0LigJPQqtCQ...
# 4  1:ZNC2F9CU0YbRjjvQpQ8+Ri/Ql1tj0LdZ0YXRnOKAmUhG...
#
#                         date                    loadingDate  \
# 0  2019-04-16T15:29:00+03:00  2019-04-16T16:36:44.928+03:00
# 1  2019-04-18T00:00:00+03:00  2019-05-13T12:53:33.523+03:00
# 2  2019-06-11T11:50:37+03:00  2019-06-11T11:50:59.877+03:00
# 3  2019-06-13T12:25:00+03:00  2019-06-13T12:35:23.006+03:00
# 4  2019-07-08T15:40:00+03:00  2019-07-08T15:52:04.527+03:00
#
#                                                title author  sourceId  \
# 0  Выставка "Связь" пройдет в московском "Экспоце...            20402
# 1  "Российская неделя высоких технологий-2019": п...            17214
# 2  В Сланцевской спортивной школе открыли мемориа...            18370
# 3                      "Он многое сделал для города"            15477
# 4  За пост губернатора Волгоградской области буду...            23264
#
#                                           sourceName  \
# 0                         Кабельщик.ру (cableman.ru)
# 1                    Information Security (itsec.ru)
# 2        Сланцевский муниципальный район (slanmo.ru)
# 3  БезФормата. ЛенОбласть (lenoblast.bezformata.com)
# 4           Выбор народа (vybor-naroda.org). Новости
#
#                                                  url  fullTextUnavailable  \
# 0  https://www.cableman.ru/content/vystavka-svyaz...                 True
# 1  http://www.itsec.ru/articles/rossiyskaya-nedel...                 True
# 2  http://www.slanmo.ru/v-slantcevskoy-sportivnoy...                 True
# 3  http://slanci.bezformata.com/listnews/mnogoe-s...                 True
# 4  http://vybor-naroda.org/lentanovostey/134340-z...                 True
#
#                                              content  \
# 0      С 23 по 26 апреля 2019 года в Центральном ...
# 1                                                ...
# 2  В 1974 в Сланцевской спортивной школе было отк...
# 3                                                ...
# 4   Восемь кандидатур выдвинуты для участия в выб...
#
#                                              objects  \
# 0  [{'type': 'company', 'id': 106273489, 'name': ...
# 1  [{'type': 'company', 'id': 6867185, 'name': 'Э...
# 2  [{'type': 'person', 'id': 18711611, 'name': 'С...
# 3  [{'type': 'company', 'id': 133030368, 'name': ...
# 4  [{'type': 'region', 'id': 318372, 'name': 'Вол...
#
#                           queryCode
# 0  813811ece60d474af4de7b29b682d3e0
# 1  813811ece60d474af4de7b29b682d3e0
# 2  813811ece60d474af4de7b29b682d3e0
# 3  813811ece60d474af4de7b29b682d3e0
# 4  813811ece60d474af4de7b29b682d3e0

# %%
company = []
company_b = []
industrialSector = []
industrialSector_b = []
region = []
region_b = []
eventType = []
eventType_b = []
for o in news['objects']:
    for ob in o:
        if ob['type'] == 'company':
            company.append(ob['name'])
        elif ob['type'] == 'industrialSector':
            industrialSector.append(ob['name'])
        elif ob['type'] == 'region':
            region.append(ob['name'])
        elif ob['type'] == 'eventType':
            eventType.append(ob['name'])
    company_b.append(set(company))
    industrialSector_b.append(set(industrialSector))
    region_b.append(set(region))
    eventType_b.append(set(eventType))
    
news['company'] = company_b
news['industrialSector'] = industrialSector_b
news['region'] = region_b
news['eventType'] = eventType_b

# %%
news = news[['queryCode', 'documentId', 'date', 'title', 'sourceName','url', 'company', 'industrialSector', 'region', 'eventType']]
news.head()
# Out:
#                           queryCode  \
# 0  813811ece60d474af4de7b29b682d3e0
# 1  813811ece60d474af4de7b29b682d3e0
# 2  813811ece60d474af4de7b29b682d3e0
# 3  813811ece60d474af4de7b29b682d3e0
# 4  813811ece60d474af4de7b29b682d3e0
#
#                                           documentId  \
# 0  1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oCm...
# 1  1:0Ycb0Y0gXAzQmDLRgALigKZfNQ0fwq7QpOKAlOKAptCm...
# 2  1:0KnQq9C54oSi0LTQlA8MB+KAucKu4oCa0IgqREo60LPQ...
# 3  1:PtCbLHIS0JDQhOKAudCL0KF10ZZuDtCkD0LigJPQqtCQ...
# 4  1:ZNC2F9CU0YbRjjvQpQ8+Ri/Ql1tj0LdZ0YXRnOKAmUhG...
#
#                         date  \
# 0  2019-04-16T15:29:00+03:00
# 1  2019-04-18T00:00:00+03:00
# 2  2019-06-11T11:50:37+03:00
# 3  2019-06-13T12:25:00+03:00
# 4  2019-07-08T15:40:00+03:00
#
#                                                title  \
# 0  Выставка "Связь" пройдет в московском "Экспоце...
# 1  "Российская неделя высоких технологий-2019": п...
# 2  В Сланцевской спортивной школе открыли мемориа...
# 3                      "Он многое сделал для города"
# 4  За пост губернатора Волгоградской области буду...
#
#                                           sourceName  \
# 0                         Кабельщик.ру (cableman.ru)
# 1                    Information Security (itsec.ru)
# 2        Сланцевский муниципальный район (slanmo.ru)
# 3  БезФормата. ЛенОбласть (lenoblast.bezformata.com)
# 4           Выбор народа (vybor-naroda.org). Новости
#
#                                                  url  \
# 0  https://www.cableman.ru/content/vystavka-svyaz...
# 1  http://www.itsec.ru/articles/rossiyskaya-nedel...
# 2  http://www.slanmo.ru/v-slantcevskoy-sportivnoy...
# 3  http://slanci.bezformata.com/listnews/mnogoe-s...
# 4  http://vybor-naroda.org/lentanovostey/134340-z...
#
#                                              company  \
# 0  {ООО Вега-Абсолют, ООО Медведевская, ООО НПП И...
# 1  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 2  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 3  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 4  {Международный Форум Международной Академии Св...
#
#                                     industrialSector  \
# 0  {Телекоммуникации и связь, Военно-промышленный...
# 1  {Телекоммуникации и связь, Военно-промышленный...
# 2  {Телекоммуникации и связь, Военно-промышленный...
# 3  {Телекоммуникации и связь, Военно-промышленный...
# 4  {Телекоммуникации и связь, Военно-промышленный...
#
#                                               region  \
# 0  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 1  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 2  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 3  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 4  {Нидерланды, Китай, Пенза (город, Пензенская О...
#
#                                            eventType
# 0  {Искусство и культура, Наука и технологии, Циф...
# 1  {Искусство и культура, Наука и технологии, Отк...
# 2  {Искусство и культура, Наука и технологии, Отк...
# 3  {Искусство и культура, Наука и технологии, Отк...
# 4  {Искусство и культура, Наука и технологии, Отк...

# %%
final_table = news.merge(result, on='queryCode', how='inner')
final_table.head()
# Out:
#                           queryCode  \
# 0  813811ece60d474af4de7b29b682d3e0
# 1  813811ece60d474af4de7b29b682d3e0
# 2  813811ece60d474af4de7b29b682d3e0
# 3  813811ece60d474af4de7b29b682d3e0
# 4  813811ece60d474af4de7b29b682d3e0
#
#                                           documentId  \
# 0  1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oCm...
# 1  1:0Ycb0Y0gXAzQmDLRgALigKZfNQ0fwq7QpOKAlOKAptCm...
# 2  1:0KnQq9C54oSi0LTQlA8MB+KAucKu4oCa0IgqREo60LPQ...
# 3  1:PtCbLHIS0JDQhOKAudCL0KF10ZZuDtCkD0LigJPQqtCQ...
# 4  1:ZNC2F9CU0YbRjjvQpQ8+Ri/Ql1tj0LdZ0YXRnOKAmUhG...
#
#                         date  \
# 0  2019-04-16T15:29:00+03:00
# 1  2019-04-18T00:00:00+03:00
# 2  2019-06-11T11:50:37+03:00
# 3  2019-06-13T12:25:00+03:00
# 4  2019-07-08T15:40:00+03:00
#
#                                                title  \
# 0  Выставка "Связь" пройдет в московском "Экспоце...
# 1  "Российская неделя высоких технологий-2019": п...
# 2  В Сланцевской спортивной школе открыли мемориа...
# 3                      "Он многое сделал для города"
# 4  За пост губернатора Волгоградской области буду...
#
#                                           sourceName  \
# 0                         Кабельщик.ру (cableman.ru)
# 1                    Information Security (itsec.ru)
# 2        Сланцевский муниципальный район (slanmo.ru)
# 3  БезФормата. ЛенОбласть (lenoblast.bezformata.com)
# 4           Выбор народа (vybor-naroda.org). Новости
#
#                                                  url  \
# 0  https://www.cableman.ru/content/vystavka-svyaz...
# 1  http://www.itsec.ru/articles/rossiyskaya-nedel...
# 2  http://www.slanmo.ru/v-slantcevskoy-sportivnoy...
# 3  http://slanci.bezformata.com/listnews/mnogoe-s...
# 4  http://vybor-naroda.org/lentanovostey/134340-z...
#
#                                            company_x  \
# 0  {ООО Вега-Абсолют, ООО Медведевская, ООО НПП И...
# 1  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 2  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 3  {ООО Вега-Абсолют, ООО Петербургский завод изм...
# 4  {Международный Форум Международной Академии Св...
#
#                                     industrialSector  \
# 0  {Телекоммуникации и связь, Военно-промышленный...
# 1  {Телекоммуникации и связь, Военно-промышленный...
# 2  {Телекоммуникации и связь, Военно-промышленный...
# 3  {Телекоммуникации и связь, Военно-промышленный...
# 4  {Телекоммуникации и связь, Военно-промышленный...
#
#                                               region  \
# 0  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 1  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 2  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 3  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 4  {Нидерланды, Китай, Пенза (город, Пензенская О...
#
#                                            eventType   company_y  totalCount  \
# 0  {Искусство и культура, Наука и технологии, Циф...  6678034985          51
# 1  {Искусство и культура, Наука и технологии, Отк...  6678034985          51
# 2  {Искусство и культура, Наука и технологии, Отк...  6678034985          51
# 3  {Искусство и культура, Наука и технологии, Отк...  6678034985          51
# 4  {Искусство и культура, Наука и технологии, Отк...  6678034985          51
#
#                                          documentIds  len_documentIds
# 0  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 1  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 2  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 3  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51
# 4  [1:LdGF0KEVTDhcLVovUHDQrQtr0KvRmGMy0ZfQt9GE4oC...               51

# %%
final_table = final_table[['company_y', 'date', 'title', 'content', 'sourceName', 'url', 'industrialSector', 'region', 'eventType', 'totalCount']]
final_table.head()
# Out:
#     company_y                       date  \
# 0  6678034985  2019-04-16T15:29:00+03:00
# 1  6678034985  2019-04-18T00:00:00+03:00
# 2  6678034985  2019-06-11T11:50:37+03:00
# 3  6678034985  2019-06-13T12:25:00+03:00
# 4  6678034985  2019-07-08T15:40:00+03:00
#
#                                                title  \
# 0  Выставка "Связь" пройдет в московском "Экспоце...
# 1  "Российская неделя высоких технологий-2019": п...
# 2  В Сланцевской спортивной школе открыли мемориа...
# 3                      "Он многое сделал для города"
# 4  За пост губернатора Волгоградской области буду...
#
#                                           sourceName  \
# 0                         Кабельщик.ру (cableman.ru)
# 1                    Information Security (itsec.ru)
# 2        Сланцевский муниципальный район (slanmo.ru)
# 3  БезФормата. ЛенОбласть (lenoblast.bezformata.com)
# 4           Выбор народа (vybor-naroda.org). Новости
#
#                                                  url  \
# 0  https://www.cableman.ru/content/vystavka-svyaz...
# 1  http://www.itsec.ru/articles/rossiyskaya-nedel...
# 2  http://www.slanmo.ru/v-slantcevskoy-sportivnoy...
# 3  http://slanci.bezformata.com/listnews/mnogoe-s...
# 4  http://vybor-naroda.org/lentanovostey/134340-z...
#
#                                     industrialSector  \
# 0  {Телекоммуникации и связь, Военно-промышленный...
# 1  {Телекоммуникации и связь, Военно-промышленный...
# 2  {Телекоммуникации и связь, Военно-промышленный...
# 3  {Телекоммуникации и связь, Военно-промышленный...
# 4  {Телекоммуникации и связь, Военно-промышленный...
#
#                                               region  \
# 0  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 1  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 2  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 3  {Нидерланды, Китай, Пенза (город, Пензенская О...
# 4  {Нидерланды, Китай, Пенза (город, Пензенская О...
#
#                                            eventType  totalCount
# 0  {Искусство и культура, Наука и технологии, Циф...          51
# 1  {Искусство и культура, Наука и технологии, Отк...          51
# 2  {Искусство и культура, Наука и технологии, Отк...          51
# 3  {Искусство и культура, Наука и технологии, Отк...          51
# 4  {Искусство и культура, Наука и технологии, Отк...          51

# %%
negative = pd.read_excel(r'C:\Users\VOLKOV_STAN\Documents\Скан-Интерфакс\Негативные темы.xlsx')
negative = set(negative['name'].unique())
negative
# Out:
# {'Авария на ЭС',
#  'Авиакатастрофа',
#  'Административные правонарушения',
#  'Акционерный конфликт',
#  'Арест и изъятие имущества',
#  'Арест судна',
#  'Аффилированность',
#  'Банковское мошенничество',
#  'Банкротства',
#  'Бенефициар',
#  'Беспорядки, конфликты и войны',
#  'Болезни',
#  'Взрыв газа',
#  'Взятки',
#  'Взяточничество',
#  'Внешнее управление',
#  'Военные преступления',
#  'Возбуждение уголовного дела',
#  'Временная администрация',
#  'Вступившие в силу решения суда',
#  'Выемки',
#  'Вымогательство взятки',
#  'Гибель человека',
#  'Глобальное потепление',
#  'ДТП',
#  'Дефолт',
#  'Должностные преступления',
#  'Дружеские связи',
#  'Жалобы клиентов банка',
#  'Жалобы потребителей',
#  'Железнодорожная катастрофа',
#  'Забастовки',
#  'Забастовки учителей',
#  'Загрязнение окружающей среды',
#  'Задолженность',
#  'Задолженность по зарплате',
#  'Займы и кредиты',
#  'Заключение под стражу',
#  'Закон о коррупции за рубежом (The Foreign Corrupt Practices Act )',
#  'Закрытие предприятия или производства',
#  'Закрытие филиала, представительства',
#  'Землетрясение',
#  'Извержение вулкана',
#  'Инвестиции',
#  'Иски о банкротствах',
#  'Катастрофы, крушения',
#  'КоАП РФ 19',
#  'КоАП РФ 19 возбуждение дела',
#  'КоАП РФ 19 предварительная проверка',
#  'КоАП РФ 19 привлечение к ответственности',
#  'КоАП РФ 19.28 возбуждение дела',
#  'КоАП РФ 19.28 предварительная проверка',
#  'КоАП РФ 19.28 привлечение к ответственности',
#  'Конкурсное производство',
#  'Контролирующие лица',
#  'Контроль и запись переговоров',
#  'Кораблекрушение',
#  'Корпоративные действия, M&A',
#  'Коррупция',
#  'Ливни и ураганы',
#  'Любовные связи',
#  'Манипулирование рынком',
#  'Митинги и реформы',
#  'Монопольное положение',
#  'Мораторий на выплаты кредиторам',
#  'Мошенничество',
#  'Наводнение',
#  'Назначения',
#  'Нанесение вреда репутации',
#  'Нападение',
#  'Наплыв клиентов',
#  'Наркотики',
#  'Нарушение закона',
#  'Нарушение обязанностей',
#  'Нарушение прав акционеров',
#  'Нарушение правил эксплуатации судна',
#  'Нарушение рекламного законодательства',
#  'Нарушение сроков исполнения контракта',
#  'Негатив о реновации',
#  'Неисправность водного транспорта',
#  'Обвал',
#  'Обвинение в коррупции',
#  'Обыски и допросы',
#  'Оползень',
#  'Отзыв банковской лицензии',
#  'Отзыв лицензии',
#  'Отзыв продукции',
#  'Отказ в кредите',
#  'Отказ от взятки',
#  'Отказ от комментария',
#  'Отмена или задержка рейса',
#  'Отмывание денег',
#  'Отставка',
#  'Отставки и назначения',
#  'Очные ставки',
#  'Падение курса акций',
#  'Падение метеорита',
#  'Падение прибыли',
#  'Падение продаж',
#  'Падение производства',
#  'Партнеры',
#  'Победа в конкурсе или тендере',
#  'Погашение задолженности',
#  'Поддержка террористов',
#  'Пожары',
#  'Пожары лесные',
#  'Поломка банкомата, отключение терминала',
#  'Получение грантов или заказов',
#  'Потери банка',
#  'Похищение',
#  'Превышение власти',
#  'Прекращение полетов',
#  'Преступления и криминал',
#  'Преступления против банка',
#  'Претензии госорганов',
#  'Привлечение к уголовной ответственности',
#  'Принудительное лечение',
#  'Проблемные закупки',
#  'Проблемные конкурсы и тендеры',
#  'Проблемы с активами',
#  'Проблемы с госзаказами',
#  'Проверки',
#  'Проекты',
#  'Простой предприятия',
#  'Противодействие коррупции',
#  'Процедура наблюдения при банкротстве',
#  'Раскрытие государственной или коммерческой тайны',
#  'Расторжение сделки, контракта',
#  'Расторжение сделки, контракта с нарушениями',
#  'Растрата денежных средств',
#  'Рейдерство, захват',
#  'Рейтинг дефолта эмитента',
#  'Реновация',
#  'Реорганизация',
#  'Родственные связи',
#  'Рост убытков',
#  'Санкции',
#  'Связи',
#  'Сделки, проекты, инвестиции',
#  'Следственные действия',
#  'Следственные опознания',
#  'Следственный осмотр и освидетельствование',
#  'Следственный эксперимент',
#  'Следствие и расследования',
#  'Слияния и Поглощения',
#  'Снижение убытков',
#  'Соучастие во взяточничестве',
#  'Спасательные операции',
#  'Статьи КоАП РФ',
#  'Статьи УК РФ',
#  'Стихийные бедствия',
#  'Строительство объектов',
#  'Судебная экспертиза',
#  'Судебные процессы с участием банка',
#  'Судебные споры, арбитражный суд',
#  'Судебный процесс',
#  'Суды, конфликты, расследования',
#  'Тендеры',
#  'Теракт',
#  'Техногенные катастрофы',
#  'УК РФ 159',
#  'УК РФ 159 возбуждение дела',
#  'УК РФ 159 предварительная проверка',
#  'УК РФ 159 привлечение к ответственности',
#  'УК РФ 159.1 возбуждение дела',
#  'УК РФ 159.1 предварительная проверка',
#  'УК РФ 159.1 привлечение к ответственности',
#  'УК РФ 159.2 возбуждение дела',
#  'УК РФ 159.2 предварительная проверка',
#  'УК РФ 159.2 привлечение к ответственности',
#  'УК РФ 159.3 возбуждение дела',
#  'УК РФ 159.3 предварительная проверка',
#  'УК РФ 159.3 привлечение к ответственности',
#  'УК РФ 159.4 возбуждение дела',
#  'УК РФ 159.4 предварительная проверка',
#  'УК РФ 159.4 привлечение к ответственности',
#  'УК РФ 159.5 возбуждение дела',
#  'УК РФ 159.5 предварительная проверка',
#  'УК РФ 159.5 привлечение к ответственности',
#  'УК РФ 159.6 возбуждение дела',
#  'УК РФ 159.6 предварительная проверка',
#  'УК РФ 159.6 привлечение к ответственности',
#  'УК РФ 201',
#  'УК РФ 201 возбуждение дела',
#  'УК РФ 201 предварительная проверка',
#  'УК РФ 201 привлечение к ответственности',
#  'УК РФ 204',
#  'УК РФ 204 возбуждение дела',
#  'УК РФ 204 предварительная проверка',
#  'УК РФ 204 привлечение к ответственности',
#  'УК РФ 290',
#  'УК РФ 290 возбуждение дела',
#  'УК РФ 290 предварительная проверка',
#  'УК РФ 290 привлечение к ответственности',
#  'УК РФ 291',
#  'УК РФ 291 возбуждение дела',
#  'УК РФ 291 предварительная проверка',
#  'УК РФ 291 привлечение к ответственности',
#  'УК РФ 291.1 возбуждение дела',
#  'УК РФ 291.1 предварительная проверка',
#  'УК РФ 291.1 привлечение к ответственности',
#  'УК РФ 304',
#  'УК РФ 304 возбуждение дела',
#  'УК РФ 304 предварительная проверка',
#  'УК РФ 304 привлечение к ответственности',
#  'Убийство',
#  'Убытки',
#  'Увольнения и сокращения',
#  'Уголовное задержание',
#  'Уголовное наказание',
#  'Уголовное обвинение',
#  'Уголовные преступления',
#  'Уменьшение доли',
#  'Урегулирование претензий государственных органов',
#  'Утечка данных',
#  'Утечка нефти',
#  'ФАС',
#  'Финансовое оздоровление',
#  'Финансовые затруднения',
#  'Финансовые результаты',
#  'Хакерские атаки',
#  'ЧП с участием банка',
#  'Чрезвычайные происшествия, чрезвычайные ситуации',
#  'Экономические преступления',
#  'Экстремизм',
#  'Эпидемии',
#  'Ядерный взрыв'}

# %%
def real_neg(x):
    if len(x & negative) > 0:
        return True
    else:
        return False

# %%
print(final_table.shape)
answer = final_table[final_table['eventType'].apply(real_neg)]
print(answer.shape)
# Out:
# (100, 9)
# (97, 9)

# %%
answer.to_excel('monitoring_scan.xlsx')
